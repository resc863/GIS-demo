# %%
import numpy as np
import pandas as pd

# %%
filename = "/content/저층주거 침수피해 시각화_20221201.csv"
df = pd.read_csv(filename, encoding="utf-8")
df.head()
# Out:
#    도형아이디    시도명 시군구명 읍면동명 법정동명      지번    도로명     건물번호  통정보   건물명  ...  \
# 0  47379  서울특별시  동작구  흑석동  흑석동   43-34  현충로6길        5  32통    \N  ...
# 1  47380  서울특별시  동작구  흑석동  흑석동   43-35  현충로6길        7  32통    \N  ...
# 2  47381  서울특별시  동작구  흑석동  흑석동   43-35  현충로6길        7  32통    \N  ...
# 3  63512  서울특별시  은평구  녹번동  녹번동  May-94  녹번로4길  03월 01일  23통  옥천빌라  ...
# 4  63513  서울특별시  은평구  녹번동  녹번동  May-94  녹번로4길  03월 01일  23통  옥천빌라  ...
#
#                     계약주소         준공일   입주형태                   지번주소  \
# 0  서울특별시 동작구 흑석동 43-34번지  1996-04-24  다가구주택  서울특별시 동작구 흑석동 43-34번지
# 1  서울특별시 동작구 흑석동 43-35번지  1993-08-27  다가구주택  서울특별시 동작구 흑석동 43-35번지
# 2  서울특별시 동작구 흑석동 43-35번지  1993-08-27  다가구주택  서울특별시 동작구 흑석동 43-35번지
# 3   서울특별시 은평구 녹번동 94-5번지  1992-12-03  다세대주택   서울특별시 은평구 녹번동 94-5번지
# 4   서울특별시 은평구 녹번동 94-5번지  1992-12-03  다세대주택   서울특별시 은평구 녹번동 94-5번지
#
#          기준년도   년도값 공간아이디       면적  등급  \
# 0  2012-01-01  2012   367    0.000   3
# 1  2012-01-01  2012   359    0.000   3
# 2  2012-01-01  2012   359    0.000   3
# 3  2013-01-01  2013    45  121.108   3
# 4  2013-01-01  2013    45  121.108   3
#
#                                         공간정보
# 0  POINT (126.965979396815 37.5068596273227)
# 1  POINT (126.965900271649 37.5068145326836)
# 2  POINT (126.965900271649 37.5068145326836)
# 3  POINT (126.930532831201 37.6056294597712)
# 4  POINT (126.930532831201 37.6056294597712)
#
# [5 rows x 23 columns]

# %%
df["longitude"] = df['공간정보'].apply(lambda x: x.split()[1][1:])
df["latitude"] = df['공간정보'].apply(lambda x: x.split()[2][:-1])

# %%
df.head()
# Out:
#    도형아이디    시도명 시군구명 읍면동명 법정동명      지번    도로명     건물번호  통정보   건물명  ...   입주형태  \
# 0  47379  서울특별시  동작구  흑석동  흑석동   43-34  현충로6길        5  32통    \N  ...  다가구주택
# 1  47380  서울특별시  동작구  흑석동  흑석동   43-35  현충로6길        7  32통    \N  ...  다가구주택
# 2  47381  서울특별시  동작구  흑석동  흑석동   43-35  현충로6길        7  32통    \N  ...  다가구주택
# 3  63512  서울특별시  은평구  녹번동  녹번동  May-94  녹번로4길  03월 01일  23통  옥천빌라  ...  다세대주택
# 4  63513  서울특별시  은평구  녹번동  녹번동  May-94  녹번로4길  03월 01일  23통  옥천빌라  ...  다세대주택
#
#                     지번주소        기준년도   년도값 공간아이디       면적 등급  \
# 0  서울특별시 동작구 흑석동 43-34번지  2012-01-01  2012   367    0.000  3
# 1  서울특별시 동작구 흑석동 43-35번지  2012-01-01  2012   359    0.000  3
# 2  서울특별시 동작구 흑석동 43-35번지  2012-01-01  2012   359    0.000  3
# 3   서울특별시 은평구 녹번동 94-5번지  2013-01-01  2013    45  121.108  3
# 4   서울특별시 은평구 녹번동 94-5번지  2013-01-01  2013    45  121.108  3
#
#                                         공간정보         longitude  \
# 0  POINT (126.965979396815 37.5068596273227)  126.965979396815
# 1  POINT (126.965900271649 37.5068145326836)  126.965900271649
# 2  POINT (126.965900271649 37.5068145326836)  126.965900271649
# 3  POINT (126.930532831201 37.6056294597712)  126.930532831201
# 4  POINT (126.930532831201 37.6056294597712)  126.930532831201
#
#            latitude
# 0  37.5068596273227
# 1  37.5068145326836
# 2  37.5068145326836
# 3  37.6056294597712
# 4  37.6056294597712
#
# [5 rows x 25 columns]

# %%
df.to_excel("output.xlsx", index=False)
